# %% [markdown]
# # VMSD Heritage Tourism Pipeline - Colab Runner
# Run this notebook after uploading the project folder to Colab.

# %%
# !pip install -r requirements.txt

# %%
# !python code/run_pipeline.py --input dataset/sample_vmsd_reviews.csv --output outputs/vmsd_predictions.csv

# %%
import pandas as pd
df = pd.read_csv('outputs/vmsd_predictions.csv')
df.head()

# %%
# !python code/evaluate_model.py --input outputs/vmsd_predictions.csv --label-column final_label --prediction-column pred_vmsd_label --output outputs/evaluation_report.json

# %%
# !python code/make_plots.py --input outputs/vmsd_predictions.csv --output-dir outputs/plots
